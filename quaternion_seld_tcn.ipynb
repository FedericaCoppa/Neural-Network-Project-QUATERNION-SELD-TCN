# %% [markdown]
# # **Neural Network Project: QUATERNION SELD-TCN**
#
# **Francesca Cardia 1759331**
#
# **Federica Coppa 1749614**

# %% [markdown]
# #### **Google drive mounting**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### **Requirements**

# %%
 # %cd "/content/drive/My Drive/QUATERNION_SELD_TCN/Code" 
 # !pip install -r requirements.txt

# %% [markdown]
# ####**Extraction of the features**

# %%
# %cd "/content/drive/My Drive/QUATERNION_SELD_TCN/Code"
# !python2 batch_feature_extraction.py

# %% [markdown]
# ####**Training phase**

# %%
# %cd "/content/drive/My Drive/QUATERNION_SELD_TCN/Code"
# !python seld.py

# %% [markdown]
# ####  **Generate plots**

# %%
# %cd "/content/drive/My Drive/QUATERNION_SELD_TCN/Code"
# !mkdir "plots"
# !python simple_plotter.py "models/foa_train[3, 4]_validation2_seq128_plot.csv"

# %% [markdown]
# ###**Test phase**

# %%
# %cd "/content/drive/My Drive/QUATERNION_SELD_TCN/Code"
# !python seld_test.py
